# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sunidhi Kumari**
#
#  My desired occupation is Data Scientist

# %% [markdown]
# *I am interested in data science because i have interest in maths and have curiosity to work with data*

# %% [markdown]
# ### The following cell of code will find the 2nd largest element from a list

# %%
list1=[1,3,2,6,5,7]
list1.sort()
print(list1[-2])
# Out:
# 6

# %% [markdown]
# Giving the description of my code...
#
# ***
#
# Code | Runs | Well
# --- | :---: | ---:
# *Gives* | **Correct** | Output
#
# * My code performs
# 1. Given input as a list
# 2. Prints the 2nd largest element from a given list
#
# [This i have learnt from](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
